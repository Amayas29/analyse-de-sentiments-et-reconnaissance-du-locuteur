# %% [markdown]
# # Classification de présidents

# %%
import codecs
import re
import string
import unicodedata
import os

from tqdm import tqdm

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize
import spacy
from wordcloud import WordCloud
from nltk.corpus import stopwords

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score
from sklearn.metrics import precision_recall_fscore_support

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

import warnings
warnings.filterwarnings("ignore")

# %%
# !python3 -m spacy download en_core_web_lg

# %%
STOP_WORDS = stopwords.words("english")
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# # Chargement des données

# %%
def load_movies(path2data):  # 1 classe par répertoire
    alltxts = []  # init vide
    labs = []
    cpt = 0
    for cl in os.listdir(path2data):  # parcours des fichiers d'un répertoire
        for f in os.listdir(path2data+cl):
            txt = open(path2data+cl+'/'+f).read()
            alltxts.append(txt)
            labs.append(cpt)
        cpt += 1  # chg répertoire = cht classe

    return alltxts, labs

# %%
path = "./datasets/movies/movies1000/"
alltxts, alllabs = load_movies(path)

# %%
print(len(alltxts), len(alllabs))
print(alltxts[0])
print(alllabs[0])
print(alltxts[-1])
print(alllabs[-1])
# Out:
# 2000 2000
# the word to describe sharon stone is " wonder " .
# not that she _is_ a wonder , but rather that i wonder how she can be so inconsistent .
# she has a dynamic screen presence in " basic instinct " , turns in a surprisingly fine acting job in " casino " , but possesses neither of those here .
# stone teams up with private school headmaster's wife isabelle adjani to kill adjani's thoroughly unlikable husband ( chazz palminteri ) .
# in a comedy of errors and unexpected twists straight out of hitchcock ( as in `homage to' [read " steal from " ] ) , it turns out that someone saw them or he's not dead or maybe . . .
# kathy bates turns in a credible , if unspectacular , performance as an investigative police detective .
# her character is a bit dull but realistic , although her actions at the end are puzzling .
# adjani is more than satisfactory as the timid beaten spouse driven to desperation .
# it's stone that is a disappointment among the actors .
# how can she be the epitome of a femme fatale in previous films and come off as a blank in this one ?
# costumed in skin-tight clothes and looking down her nose at everyone , she is someone you would want to avoid because she is boring , not enticingly dangerous .
# even the threat ( or promise ? ) of a lesbian relationship between the conspirators is only half played out .
# on the positive side , there are enough unexpected plot developments to keep your interest alive .
# that is if you can put up with stone's cardboard cut-out character and scenes directly lifted from hitch's movies .
#
# 0
# bob the happy bastard's quickie review :
# rush hour
# so what's the problem with 48 hours clones these days ?
# they always try for the same thing that eddie murphy and nick nolte had .
# that was the problem that plagued these clones , not to mention the actual sequel : another 48 hours , a complete waste of film .
# but , at last , someone has a different take on the matter , and it's director brett rainer .
# rush hour features jackie chan in his first u . s . action movie , playing a chinese detective who's being flown to the us to investigate the kidnapping of the chinese consulate's daughter .
# of course , the fbi is upset that he'll be interfering in their investigation , and stick him with an lapd office with a big mouth- of course , that's chris tucker .
# what makes rush hour work so damn well is the chemistry between the energetic chan and the absolutely hilarious tucker .
# tucker mouths off to chan at every given opportunity ( " i'm michael jackson , you tito . " ) , and chan delivers a few zingers of his own , as well as some terrific fight scenes .
# the story's pretty much your average fare , but with a decent twist involving the main villain , a highly clouded figure named jun tao .
# at least it's entertaining , and the concept is excellently realized .
# a particular fight scene in a chinese office , where chan and tucker duke it out with the bad guys , is funny and energetic at the same time .
# and the finale's a real treat as well . . . chan
# delivers yet another fantastic stunt for the fans with a 10-story drop .
# rush hour is just the sort of film you'll get a kick out of on any night of the week .
# just make sure you don't look for anything culturally different and you'll be fine- drunken master ii this ain't .
#
# 1

# %%
np.unique(alllabs)  # nos labels
# Out:
# array([0, 1])

# %% [markdown]
# ## A) Transformation paramétrique du texte (pre-traitements)

# %% [markdown]
# - Train/Test split des données :

# %%
index = np.arange(len(alltxts))
Xtrain, Xtest, ytrain, ytest = train_test_split(
    alltxts, alllabs, stratify=alllabs)

# %% [markdown]
# - Appliquer une lemmatisation sur la base d'entrainement (Pour des questions d'optimisation)

# %%
def lemmatize_text(text):
    tokens = word_tokenize(text)
    docs = list(nlp.pipe(tokens, disable=["parser", "ner"]))
    tokens_lem = [doc[0].lemma_ for doc in docs]
    text = ' '.join(tokens_lem)
    return text


def lemmatize_data(data):
    lemmatize_text_vec = np.vectorize(lemmatize_text)
    data_lem = lemmatize_text_vec(data)
    return data_lem


if "Xtrain_lem" not in globals():
    Xtrain_lem = lemmatize_data(Xtrain)

# %%
def preprocess_strat(text, X):

    punc = string.punctuation
    punc += '\n\r\t'
    text = text.translate(str.maketrans(punc, ' ' * len(punc)))

    text = unicodedata.normalize('NFD', text).encode(
        'ascii', 'ignore').decode("utf-8")
    text = re.sub('(www|http)[\w\.-_]+\.(fr|com|org)', 'URL', text)

    if X["ToLower"]:
        text = text.lower()

    if X["DeleteNumbers"]:
        text = re.sub('[0-9]+', '', text)

    return text


def fit(X, force_count_vec=False):
    preprocess = None
    stopwords = None
    ngram_range = (1, 1)
    use_idf = True
    min_df = 1
    max_df = 1.0
    max_features = None
    binary = False
    data = Xtrain
    count_vec = True

    if X is not None:
        def preprocess(text): return preprocess_strat(text, X)

        if "stopwords" in X:
            stopwords = X["stopwords"]
        if "ngram_range" in X:
            ngram_range = X["ngram_range"]
        if "use_idf" in X:
            use_idf = X["use_idf"]
        if "min_df" in X:
            min_df = X["min_df"]
        if "max_df" in X:
            max_df = X["max_df"]
        if "max_features" in X:
            max_features = X["max_features"]
        if "binary" in X:
            binary = X["binary"]
        if "lemmatized" in X and X["lemmatized"]:
            data = Xtrain_lem
        
        if not force_count_vec and "count_vec" in X:
            count_vec = X["count_vec"]

    if count_vec:
        vectorizer = CountVectorizer(
            preprocessor=preprocess, stop_words=stopwords)
        return vectorizer.fit_transform(data), vectorizer

    vectorizer = TfidfVectorizer(preprocessor=preprocess, stop_words=stopwords, ngram_range=ngram_range, use_idf=use_idf,
                                 min_df=min_df, max_df=max_df, max_features=max_features, binary=binary)

    return vectorizer.fit_transform(data), vectorizer

# %%
X1 = {
    "name": "Lower | Not Number | Stop Words",
    "ToLower": True,
    "DeleteNumbers": True,
    "stopwords": STOP_WORDS,
    "lemmatized": True,
    "count_vec": False,
}

# %%
strats = [X1]

# %% [markdown]
# # B) Extraction du vocabulaire (BoW)
# - **Exploration préliminaire des jeux de données**

# %%
X_base, vectorizer = fit(None)

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['00', '000', '0009f', ..., 'zwigoff', 'zycie', 'zzzzzzz'],
#       dtype=object)

# %% [markdown]
# Quelle est la taille d'origine du vocabulaire?

# %%
X_base.shape[1]
# Out:
# 35506

# %%
def get_wordcloud(X, count_vec, odd_ratio=False):

    vectors, vectorizer = fit(X, force_count_vec=count_vec)

    if not odd_ratio:
        counts = np.array(vectors.sum(axis=0))[0]
    else:
        # Classe 1
        p = np.array(vectors[ytrain == 1].sum(axis=0))[0]
        # Classe -1
        q = np.array(vectors[ytrain == 0].sum(axis=0))[0]

        odds1 = p * (1 - q)
        odds2 = q * (1 - p)

        odds_ratio = np.where(odds2 == 0, 0, odds1 / odds2)

    dico = dict()
    words = vectorizer.get_feature_names_out()

    for i in range(len(words)):
        w = words[i]
        if not odd_ratio:
            dico[w] = counts[i]
        else:
            dico[w] = odds_ratio[i]

    return WordCloud(background_color='white', stopwords=[],
                     max_words=100).generate_from_frequencies(dico)

# %% [markdown]
# Que reste-t-il si on ne garde que les 100 mots les plus fréquents? [word cloud]

# %%
fig, axs = plt.subplots(1, len(strats)+1, figsize=(20, 5))

wordcloud = get_wordcloud(None, count_vec=True)
axs[0].imshow(wordcloud)
axs[0].set_title('Vocabulaire initiale')
axs[0].axis("off")

for i, X in enumerate(strats):
    wordcloud = get_wordcloud(X, count_vec=True)
    axs[i+1].imshow(wordcloud)
    axs[i+1].set_title(X["name"])
    axs[i+1].axis("off")

plt.suptitle("Wordcloud des 100 mots les plus fréquents dans deux vocabulaires")
plt.show()

# %% [markdown]
# Quels sont les 100 mots dont la fréquence documentaire est la plus grande? [word cloud]

# %%
fig, axs = plt.subplots(1, len(strats)+1, figsize=(20, 5))

wordcloud = get_wordcloud(None, count_vec=False)
axs[0].imshow(wordcloud)
axs[0].set_title('Vocabulaire initiale')
axs[0].axis("off")

for i, X in enumerate(strats):
    wordcloud = get_wordcloud(X, count_vec=False)
    axs[i+1].imshow(wordcloud)
    axs[i+1].set_title(X["name"])
    axs[i+1].axis("off")

plt.suptitle("Wordcloud des 100 mots dont le Idf est max dans deux vocabulaires")
plt.show()

# %% [markdown]
# Quels sont les 100 mots les plus discriminants au sens de odds ratio? [word cloud]

# %%
fig, axs = plt.subplots(1, len(strats)+1, figsize=(20, 5))

wordcloud = get_wordcloud(None, count_vec=True, odd_ratio=True)
axs[0].imshow(wordcloud)
axs[0].set_title('Vocabulaire initiale')
axs[0].axis("off")

for i, X in enumerate(strats):
    wordcloud = get_wordcloud(X, count_vec=True, odd_ratio=True)
    axs[i+1].imshow(wordcloud)
    axs[i+1].set_title(X["name"])
    axs[i+1].axis("off")

plt.suptitle("Wordcloud des 100 mots les plus discriminants au sens de odds ratio dans deux vocabulaires")
plt.show()

# %% [markdown]
# Quelle est la distribution d'apparition des mots (Zipf)

# %%
fig, axs = plt.subplots(1, len(strats)+1, figsize=(20, 5))

vectors, vectorizer = fit(None, force_count_vec=True)
counts = np.array(vectors.sum(axis=0))[0]
index = counts.argsort()[::-1]
axs[0].plot(counts[index])
axs[0].set_title('Vocabulaire initiale')
axs[0].set_xticklabels(vectorizer.get_feature_names_out(), rotation=90)

for i, X in enumerate(strats):
    vectors, vectorizer = fit(X, force_count_vec=True)
    counts = np.array(vectors.sum(axis=0))[0]
    index = counts.argsort()[::-1]
    axs[i+1].plot(counts[index])
    axs[i+1].set_title(X["name"])
    axs[i+1].set_xticklabels(vectorizer.get_feature_names_out(), rotation=90)

plt.suptitle("Distibution d'apparition des mots dans deux vocabularies")
plt.show()

# %% [markdown]
# Quels sont les 100 bigrammes/trigrammes les plus fréquents?

# %%
X_bi = {
    "name": "Lower | Not Number | Stop Words | Bi-gram",
    "ToLower": True,
    "DeleteNumbers": True,
    "stopwords": STOP_WORDS,
    "ngram_range": (2, 2),
    "lemmatized": True,
    "count_vec": False,
}

X_tri = {
    "name": "Lower | Not Number | Stop Words | Tri-gram",
    "ToLower": True,
    "DeleteNumbers": True,
    "stopwords": STOP_WORDS,
    "ngram_range": (3, 3),
    "lemmatized": True,
    "count_vec": False,
}

for X in [X_bi, X_tri]:
    wordcloud = get_wordcloud(X, count_vec=False)
    plt.imshow(wordcloud)
    plt.title(X["name"])
    plt.show()

# %% [markdown]
# - **Variantes de BoW**

# %%
strats = []

strats.append({
    "name": "Lower | Not Number | Stop Words | TF",
    "ToLower": True,
    "DeleteNumbers": True,
    "stopwords": STOP_WORDS,
    "use_idf": False,
    "lemmatized": True,
    "count_vec": False,
})

strats.append({
    "name": "Lower | Not Number | Stop Words | TF",
    "ToLower": True,
    "DeleteNumbers": True,
    "stopwords": STOP_WORDS,
    "lemmatized": True,
    "count_vec": True,
})

strats.append({
    "name": "Lower | Not Number | Stop Words | min_max_df",
    "ToLower": True,
    "DeleteNumbers": True,
    "stopwords": STOP_WORDS,
    "min_df": 10,
    "max_df": 0.93,
    "lemmatized": True,
    "count_vec": False,
})

strats.append({
    "name": "Lower | Not Number | Stop Words | min_max_df",
    "ToLower": True,
    "DeleteNumbers": True,
    "stopwords": STOP_WORDS,
    "min_df": 6,
    "max_df": 0.95,
    "lemmatized": True,
    "max_features": 10000,
    "count_vec": False,
})

strats.append({
    "name": "Lower | Not Number | Stop Words | Binary",
    "ToLower": True,
    "DeleteNumbers": True,
    "stopwords": STOP_WORDS,
    "binary": True,
    "lemmatized": True,
    "count_vec": False,
})

strats.append({
    "name": "Lower | Not Number | Stop Words | Bi-gram",
    "ToLower": True,
    "DeleteNumbers": True,
    "stopwords": STOP_WORDS,
    "ngram_range": (2, 2),
    "lemmatized": True,
    "count_vec": False,
    "min_df": 7,
    "max_df": 0.95,
})

# %%
for X in strats:
    vectors, vectorizer = fit(X)
    X["base"] = vectors
    X["vectorizer"] = vectorizer

# %% [markdown]
# # C) Modèles de Machine Learning

# %%
def eval_model(labels, y_hat):
    scores = {}
    scores["f1_score"] = f1_score(labels, y_hat)
    scores["accuracy"] = accuracy_score(labels, y_hat)
    scores["auc_roc"] = roc_auc_score(labels, y_hat)
    return scores

# %%
if "Xtest_lem" not in globals():
    Xtest_lem = lemmatize_data(Xtest)

Xtest_lem
# Out:
# array(["capsule : earthy , experimental , difficult , shockingly frank ( even for 1997 ! ) , and ultimately refreshing story of a black man on the run from the cop . the first few minute of sweet sweetback be baad asssss song ( yes , I check -- that be the correct number of ss ) be without dialogue , just eerie montage of sound . a young boy , obviously malnourished , be take in and feed up by several love mother figure . then one of they take the boy to bed for a sexual initation ( underneath the title credit ) that be far more confrontatory and shocking than any ten basic instinct -- probably because it have the directness and clumsiness of real life , something we be not use to see on screen . this be one tough movie to swallow , no matter who you be , but that probably reflect more on how pallid and unchallenging movie have get lately . ( I suspect the sex scene in movie
#       dtype='<U10870')

# %%
def optimize_strats(lstrats, optimizer, model_name, sample, scoring="f1_macro"):
    
    if sample is not None:
            model_name = f"{model_name}_{sample}"
            
    for X in tqdm(lstrats):            
        X[model_name] = optimizer(X, scoring=scoring, sample=sample)

# %%
def get_scores(lstrats, model_name, sample):
    
    if sample is not None:
        model_name = f"{model_name}_{sample}"
        
    for X in tqdm(lstrats):
        Xtest_tran = X["vectorizer"].transform(Xtest_lem)
        y_hat = X[model_name].predict(Xtest_tran)
        X[f"scores_{model_name}"] = eval_model(ytest, y_hat)
        precision, recall, _, _ = precision_recall_fscore_support(ytest, y_hat)
        X[f"precision_{model_name}"] = precision
        X[f"recall_{model_name}"] = recall

# %%
def lineplot(scores, ax, score_name):
    sns.lineplot(x=list(range(1, len(scores)+1)),
                y=scores, color='steelblue', ax=ax, linestyle='--', marker='o')
    
    ax.set_xlabel('Numéro de la strategie')
    ax.set_ylabel(score_name)
    ax.set_title(f'Distribution des scores {score_name}')

def optimization_report(lstrats, model_name, sample):
    f1_scores = []
    accuracy_scores = []
    roc_auc_scores = []

    if sample is not None:
        model_name = f"{model_name}_{sample}"
        
    scores_names = f"scores_{model_name}"

    for i, X in enumerate(lstrats):
        f1_scores.append(X[scores_names]['f1_score'])
        accuracy_scores.append(X[scores_names]['accuracy'])
        roc_auc_scores.append(X[scores_names]['auc_roc'])
    
    fig, axs = plt.subplots(1, 3, figsize=(12, 4))
    lineplot(f1_scores, axs[0], "F1 score")
    lineplot(accuracy_scores, axs[1], "Accuracy")
    lineplot(roc_auc_scores, axs[2], "AUC-ROC")
    plt.tight_layout()
    plt.show()

# %%
def reglog_optimizer(X, sample, scoring='f1_macro'):
    reglog = LogisticRegression(max_iter=2000, class_weight="balanced")
    params = {'C': [0.01, 0.1, 0.5, 1, 2], 'penalty': ['l2', None]}
    cv = StratifiedKFold(n_splits=5, shuffle=True)

    grid = GridSearchCV(reglog, params, cv=cv, n_jobs=-1, scoring=scoring)
    
    if sample is None:
        grid.fit(X["base"], ytrain)
    else:
        grid.fit(X[f"X_{sample}"], X[f"y_{sample}"])
        
    return grid.best_estimator_

# %%
optimize_strats(strats, reglog_optimizer, "reglog", None)
# Out:
# 100%|██████████| 6/6 [00:49<00:00,  8.31s/it]

# %%
get_scores(strats, "reglog", None)
# Out:
# 100%|██████████| 6/6 [00:01<00:00,  4.04it/s]

# %%
optimization_report(strats, "reglog", None)

# %%
def rf_optimizer(X, sample, n_estimators=100, scoring='f1_macro'):
    rf = RandomForestClassifier(
        n_estimators=n_estimators, class_weight='balanced')
    params = {'max_depth': [5, 7, 12], 'min_samples_split': [5, 10, 20, 30]}
    cv = StratifiedKFold(n_splits=5, shuffle=True)

    grid = RandomizedSearchCV(rf, params, cv=cv, n_jobs=-1, scoring=scoring)
    
    if sample is None:
        grid.fit(X["base"], ytrain)
    else:
        grid.fit(X[f"X_{sample}"], X[f"y_{sample}"])
        
    return grid.best_estimator_

# %%
optimize_strats(strats, rf_optimizer, "rf", None)
# Out:
# 100%|██████████| 6/6 [00:27<00:00,  4.65s/it]

# %%
get_scores(strats, "rf", None)
# Out:
# 100%|██████████| 6/6 [00:01<00:00,  3.84it/s]

# %%
optimization_report(strats, "rf", None)

# %%
def bnb_optimizer(X, sample, scoring=None):
    bnb = BernoulliNB()
        
    if sample is None:
        bnb.fit(X["base"], ytrain)
    else:
        bnb.fit(X[f"X_{sample}"], X[f"y_{sample}"])
        
    return bnb

# %%
optimize_strats(strats, bnb_optimizer, "bnb", None)
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 43.78it/s]

# %%
get_scores(strats, "bnb", None)
# Out:
# 100%|██████████| 6/6 [00:03<00:00,  1.75it/s]

# %%
optimization_report(strats, "bnb", None)

# %%
def svm_optimizer(X, sample, scoring="f1_macro"):
    svm = LinearSVC(class_weight='balanced', max_iter=4000)
    params = {'C': [0.001, 0.1, 0.5, 1, 1.5], 'penalty': ["l1", "l2"]}
    
    cv = StratifiedKFold(n_splits=4, shuffle=True)
    grid = RandomizedSearchCV(svm, params, cv=cv, n_jobs=-1, scoring=scoring)
        
    if sample is None:
        grid.fit(X["base"], ytrain)
    else:
        grid.fit(X[f"X_{sample}"], X[f"y_{sample}"])
    
    return grid.best_estimator_

# %%
optimize_strats(strats, svm_optimizer, "svm", None)
# Out:
# 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]

# %%
get_scores(strats, "svm", None)
# Out:
# 100%|██████████| 6/6 [00:05<00:00,  1.13it/s]

# %%
optimization_report(strats, "svm", None)

# %% [markdown]
# ## Test

# %%
strat_max = None
model_max = None
score_max = 0

for X in strats:
    for model in ["reglog", "svm", "rf", "bnb"]:
        score = (X[f"scores_{model}"]["f1_score"] + X[f"scores_{model}"]["auc_roc"]) / 2
        
        if score > score_max:
            score_max = score
            strat_max = X
            model_max = model

# %%
def load_movies_test(filename):
    
    with open(filename, "r") as f:
        testtxts = f.readlines()

    return np.array(testtxts)

# %%
fname = "./datasets/movies/testSentiment.txt"
testtxts = load_movies_test(fname)
testtxts.shape
# Out:
# (25000,)

# %%
# if "Xval_lem" not in globals():
#     Xval_lem = lemmatize_data(testtxts)

# Xval_lem
# Out:
# array(['story of a man who have unnatural feeling for a pig . start out with a opening scene that be a terrific example of absurd comedy . a formal orchestra audience be turn into an insane , violent mob by the crazy chantings of it be singer . unfortunately it stay absurd the whole time with no general narrative eventually make it just too off put . even those from the era should be turn off . the cryptic dialogue would make Shakespeare seem easy to a third grader . on a technical level it be well than you might think with some good cinematography by future great Vilmos zsigmond . future star sally Kirkland and Frederic Forrest can be see briefly .',
#        "I see ' ' last night at the Stockholm film festival and it be one huge disappointment . disappointment because the storyline be potentially powerful , the prospect of see Rosario Dawson in a small intimate movie be exciting and , be a fan ( sound pervy , I ' not ! ) of ' ' flick of the 70 be , I be needless to say very curious to check this movie out . my conclusion : let be stick to the classic ! yes , the storyline have potential but the dialog be flat , the actor unconvincing . even Dawson be empty . some would say that it be a right depiction of the college world in the US , that the emptiness of the character serve a purpose and all that jazz but it just make the whole movie unsubstantial . just like the scene where Dawson get rape : it seriously lack intensity ! I be not expect anything ' but still , be not we suppose to feel compassion for her ? I do not . not for a minute , she be so lame all the way ; - ) and I read that the photography be impressive . well , it be good indeed but nothing ground either . I must admit that the screen at the festival be not so good so maybe I miss out something here but at the end of the movie , I could not help think ' I feel like watch Argento be ' ' again . lol . More seriously , the first scene in the club be beautifully shoot and all but I have the bitter sensation of watch a long and more bore version of the scene in the filthy bar near the American border in Lynch be ' peak - fire walk with I ' ... the crude red and blue light , the heavy bass music , the general lascivious atmosphere ... no , I just could not get into this movie . too bad .",
#        "some film that you pick up for a pound turn out to be rather good - 23rd Century film release dozen of obscure italian and american movie that be great , but although hardgore release some Fulci film amongst other , the bulk of their output be crap like the zombie chronicle < br / > < br / > the only positive thing I can say about this film be that it be nowhere near as annoying as the stink of flesh . other than that , its a very clumsy anthology film with the technical competence of a lego house build by a whelk < br / > < br / > it be be note elsewhere , but you really do have to worry about a film that insert preview of the action into its credit sequence , so by the time it get to the zombie attack , you ' see it all already < br / > < br / > bad movie fan will have a ball watch the 18,000 continuity mistake and the diabolical act of the cast ( especially the hitchhiker , who be so bad he do make I laugh a bit ) , and kudo to hardgore for get in to the spirit of thing by release a print so bad it feel like I be watch some beat up home video of a camping trip < br / > < br / > awful , awful stuff . we ' all make stuff like this when we ' get a hold of a camera , but common sense prevail and these film languish in our cupboard somewhere . avoid .",
#        "this be one of the dumb film , I ' ever see . it rip off nearly ever type of thriller and manage to make a mess of they all < br / > < br / > there be not a single good line or character in the whole mess . if there be a plot , it be an afterthought and as far as act go , there be nothing good to say so Ill say nothing . I honestly can understand how this type of nonsense get produce and actually release , do somebody somewhere not at some stage think , ' my god this really be a load of shite ' and call it a day . its crap like this that have people download illegally , the trailer look like a completely different film , at least if you have download it , you have not waste your time or money do not waste your time , this be painful ."],
#       dtype='<U13423')

# %%
# with open("./datasets/movies/testSentiment_lemma.txt", "w") as f:
#     f.write("\n".join(Xval_lem))

# %% [markdown]
# - Max (f1_score + auc_roc) / 2

# %%
# X_lem = np.concatenate((Xtrain_lem.reshape(-1, ), Xtest_lem.reshape(-1, )), axis=0)
# y_lem = np.concatenate((np.array(ytrain).reshape(-1, ), np.array(ytest).reshape(-1, )), axis=0)

# %%
# X_lem_trans = strat_max["vectorizer"].transform(X_lem)
# strat_max[model_max].fit(X_lem_trans, y_lem)
# Out:
# LinearSVC(C=1, class_weight='balanced', max_iter=4000)

# %%
# Xval_tran = strat_max["vectorizer"].transform(Xval_lem)
# y_hat = strat_max[model_max].predict(Xval_tran)

# %%
# with open("push_1", "w") as f:
#     f.write("\n".join(np.where(y_hat == 0, "N", "P")))
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
